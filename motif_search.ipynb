# %% [markdown]
# ## Code for motif search

# %%
# %%bash
#
# cd /Users/alena/Desktop/thesis/500_model_1_epoch/motifs
#
# export KMER=6
# export DATA_PATH=/Users/alena/Desktop/thesis/500_model_1_epoch/data
# export PREDICTION_PATH=/Users/alena/Desktop/thesis/500_model_1_epoch/results
# export MOTIF_PATH=./results/$KMER
#
# python find_motifs.py \
#     --data_dir $DATA_PATH \
#     --predict_dir $PREDICTION_PATH \
#     --window_size 15 \
#     --min_len 7 \
#     --pval_cutoff 0.001 \
#     --min_n_motif 5 \
#     --align_all_ties \
#     --save_file_dir $MOTIF_PATH \
#     --verbose
# Out:
# *** Begin motif analysis ***
# * pos_seqs: 8156; neg_seqs: 8521
# * Finding high attention motif regions
# * Filtering motifs by hypergeometric test
# motif CAGCGGT: N=16677; K=8156; n=198; x=145; p=2.0956309217318948e-12
# motif GTCTGGG: N=16677; K=8156; n=658; x=388; p=8.155305120388807e-08
# motif GCCGCCCTG: N=16677; K=8156; n=25; x=23; p=5.996158815411054e-06
# motif CTTTCCC: N=16677; K=8156; n=1206; x=688; p=2.4803628453194465e-09
# motif GGCCCAGT: N=16677; K=8156; n=132; x=90; p=5.412903504902139e-06
# motif AGGCTCT: N=16677; K=8156; n=833; x=478; p=2.9998007886029005e-07
# motif GGGACTC: N=16677; K=8156; n=588; x=374; p=2.039446650721147e-13
# motif GGGATTT: N=16677; K=8156; n=828; x=485; p=6.628426720723588e-09
# motif AGCTGTG: N=16677; K=8156; n=1088; x=608; p=1.1077690105467e-06
# motif GGAGGGG: N=16677; K=8156; n=1259; x=800; p=1.285870849741913e-27
# motif GGCCACCT: N=16677; K=8156; n=161; x=108; p=2.188050136890166e-06
# ...
